# %%
import pandas as pd
import folium

# %%
map = folium.Map(location = [20.5937, 78.9629],
                zoom_start=5)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.read_csv("datafile.csv")
df.head(5)
# Out:
#             Category of States          States  Hindus - Males  \
# 0  Non Special Category States  Andhra Pradesh            14.6
# 1  Non Special Category States           Assam            12.0
# 2  Non Special Category States           Bihar            20.0
# 3  Non Special Category States    Chhattisgarh            13.6
# 4  Non Special Category States           Delhi            10.7
#
#    Hindus - Females  Hindus - Persons  Muslims - Males  Muslims - Females  \
# 0              18.0              16.3             15.2               26.7
# 1              17.0              14.2             17.0               21.6
# 2              29.2              23.9             36.5               44.0
# 3              19.9              16.6             25.7                8.4
# 4              10.4              10.6             23.0               28.9
#
#    Muslims - Persons  Christians - Males  Christians - Females  \
# 0               21.2                18.1                  13.7
# 1               18.9                 0.3                  39.4
# 2               39.8                21.6                  11.3
# 3               16.7                13.2                  18.6
# 4               25.6                 NaN                   NaN
#
#    Christians - Persons  Sikhs - Males  Sikhs - Females  Sikhs - Persons
# 0                  15.8            NaN              NaN              NaN
# 1                  22.7            NaN              NaN              NaN
# 2                  16.2            NaN              NaN              NaN
# 3                  15.5            NaN              NaN              NaN
# 4                   NaN            NaN              NaN              NaN

# %%
df_states = df.set_index("States")

df_states.fillna(0)
# Out:
#                                Category of States  Hindus - Males  \
# States
# Andhra Pradesh        Non Special Category States            14.6
# Assam                 Non Special Category States            12.0
# Bihar                 Non Special Category States            20.0
# Chhattisgarh          Non Special Category States            13.6
# Delhi                 Non Special Category States            10.7
# Goa                   Non Special Category States            15.2
# Gujarat               Non Special Category States            16.0
# Haryana               Non Special Category States            11.4
# Jharkhand             Non Special Category States            18.8
# Karnataka             Non Special Category States            13.1
# Kerala                Non Special Category States             4.2
# Madhya Pradesh        Non Special Category States            17.1
# Maharashtra           Non Special Category States            13.5
# Orissa                Non Special Category States            21.4
# Punjab                Non Special Category States            21.9
# Raja st ha n          Non Special Category States            12.9
# Tamil Nadu            Non Special Category States            10.3
# Uttar Pradesh         Non Special Category States            16.2
# West Bengal           Non Special Category States            16.2
# Arunachal Pradesh         Special Category States             5.8
# Himachal Pradesh          Special Category States             4.3
# Jammu & Kashmir           Special Category States             6.1
# Manipur                   Special Category States             4.6
# Meghalaya                 Special Category States             9.6
# Mizoram                   Special Category States             0.0
# Nagaland                  Special Category States            29.5
# Sikkim                    Special Category States             6.3
# Tripura                   Special Category States            15.8
# Uttarakhand               Special Category States             7.9
# Andaman & Nicobar               Union Territories             4.9
# Chandigarh                      Union Territories            11.4
# Dadra & Nagar Haveli            Union Territories             7.9
# Daman & Diu                     Union Territories             9.6
# Lakshadweep                     Union Territories             0.0
# Puducherry                      Union Territories             7.4
#
#                       Hindus - Females  Hindus - Persons  Muslims - Males  \
# States
# Andhra Pradesh                    18.0              16.3             15.2
# Assam                             17.0              14.2             17.0
# Bihar                             29.2              23.9             36.5
# Chhattisgarh                      19.9              16.6             25.7
# Delhi                             10.4              10.6             23.0
# Goa                               15.3              15.3             20.9
# Gujarat                           25.0              20.1             28.1
# Haryana                           18.4              14.4             26.8
# Jharkhand                         20.9              19.7             23.4
# Karnataka                         16.5              14.8             17.5
# Kerala                             2.8               3.5              3.5
# Madhya Pradesh                    21.1              18.9             22.9
# Maharashtra                       15.8              14.6             20.6
# Orissa                            28.5               0.0             32.0
# Punjab                            17.5              20.0             15.2
# Raja st ha n                      27.4              19.4             27.0
# Tamil Nadu                         9.8              10.1             11.1
# Uttar Pradesh                     18.6              17.3             33.6
# West Bengal                       17.4              16.7             29.2
# Arunachal Pradesh                 11.4               8.5              4.6
# Himachal Pradesh                   5.4               4.8              9.2
# Jammu & Kashmir                    9.7               7.9              9.1
# Manipur                            8.8               6.6             14.3
# Meghalaya                          5.3               7.2              1.4
# Mizoram                            0.0               0.0              0.0
# Nagaland                          46.3              37.9             47.1
# Sikkim                             8.5               7.3              0.0
# Tripura                           15.3              15.6             22.4
# Uttarakhand                       10.6               9.2             31.3
# Andaman & Nicobar                  4.5               4.7              7.7
# Chandigarh                        22.8              15.8             35.4
# Dadra & Nagar Haveli              29.0              16.1              0.0
# Daman & Diu                       12.6              10.8              0.0
# Lakshadweep                        0.0               0.0              5.4
# Puducherry                        10.0               8.5              6.1
#
#                       Muslims - Females  Muslims - Persons  \
# States
# Andhra Pradesh                     26.7               21.2
# Assam                              21.6               18.9
# Bihar                              44.0               39.8
# Chhattisgarh                        8.4               16.7
# Delhi                              28.9               25.6
# Goa                                37.2               26.9
# Gujarat                            44.0               35.7
# Haryana                            46.4               36.0
# Jharkhand                          28.6               25.9
# Karnataka                          19.2               18.4
# Kerala                              3.3                3.4
# Madhya Pradesh                     22.0               22.4
# Maharashtra                        29.4               24.9
# Orissa                             43.0               37.9
# Punjab                             35.5               24.9
# Raja st ha n                       37.3               31.7
# Tamil Nadu                         10.3               10.7
# Uttar Pradesh                      41.0               37.2
# West Bengal                        24.4               26.9
# Arunachal Pradesh                   3.0                4.0
# Himachal Pradesh                   25.2               17.4
# Jammu & Kashmir                    18.5               13.6
# Manipur                            29.5               20.3
# Meghalaya                           9.7                4.8
# Mizoram                             0.0                0.0
# Nagaland                           45.5               46.1
# Sikkim                              0.0                0.0
# Tripura                            19.6               21.0
# Uttarakhand                        29.9               30.6
# Andaman & Nicobar                   4.9                6.4
# Chandigarh                         48.4               40.2
# Dadra & Nagar Haveli                0.0                0.0
# Daman & Diu                         0.0                0.0
# Lakshadweep                         7.1                6.2
# Puducherry                         10.0                7.7
#
#                       Christians - Males  Christians - Females  \
# States
# Andhra Pradesh                      18.1                  13.7
# Assam                                0.3                  39.4
# Bihar                               21.6                  11.3
# Chhattisgarh                        13.2                  18.6
# Delhi                                0.0                   0.0
# Goa                                  0.0                   0.0
# Gujarat                             18.1                   7.9
# Haryana                              0.0                   0.0
# Jharkhand                           23.7                  24.7
# Karnataka                            0.0                   0.0
# Kerala                               2.4                   2.4
# Madhya Pradesh                       0.0                   0.0
# Maharashtra                         21.9                  22.6
# Orissa                              17.7                  18.9
# Punjab                              19.6                  16.2
# Raja st ha n                        46.4                 100.0
# Tamil Nadu                           5.0                   6.6
# Uttar Pradesh                        0.0                   0.0
# West Bengal                          6.0                  20.5
# Arunachal Pradesh                   16.2                  19.2
# Himachal Pradesh                     0.0                   0.0
# Jammu & Kashmir                      0.0                   0.0
# Manipur                              7.8                  12.2
# Meghalaya                            9.7                   9.0
# Mizoram                              5.5                   5.8
# Nagaland                             4.9                   8.3
# Sikkim                              15.1                  10.8
# Tripura                             13.8                  49.8
# Uttarakhand                          0.0                   0.0
# Andaman & Nicobar                    5.5                  18.2
# Chandigarh                           0.0                   0.0
# Dadra & Nagar Haveli                 0.0                   0.0
# Daman & Diu                          0.0                   0.0
# Lakshadweep                          0.0                   0.0
# Puducherry                           0.0                   0.0
#
#                       Christians - Persons  Sikhs - Males  Sikhs - Females  \
# States
# Andhra Pradesh                        15.8            0.0              0.0
# Assam                                 22.7            0.0              0.0
# Bihar                                 16.2            0.0              0.0
# Chhattisgarh                          15.5            0.0              0.0
# Delhi                                  0.0            0.0              0.0
# Goa                                    0.0            0.0              0.0
# Gujarat                               12.6            0.0              0.0
# Haryana                                0.0           10.7             20.5
# Jharkhand                             24.1            0.0              0.0
# Karnataka                              0.0            0.0              0.0
# Kerala                                 2.4            0.0              0.0
# Madhya Pradesh                         0.0            0.0              0.0
# Maharashtra                           22.3            0.0              0.0
# Orissa                                18.3            0.0              0.0
# Punjab                                17.8           16.6             21.3
# Raja st ha n                          65.1           24.6             42.6
# Tamil Nadu                             5.9            0.0              0.0
# Uttar Pradesh                          0.0            6.5             23.5
# West Bengal                           14.2            0.0              0.0
# Arunachal Pradesh                     17.6            0.0              0.0
# Himachal Pradesh                       0.0            0.0              0.0
# Jammu & Kashmir                        0.0            0.0              0.0
# Manipur                                9.8            0.0              0.0
# Meghalaya                              9.4            0.0              0.0
# Mizoram                                5.6            0.0              0.0
# Nagaland                               6.5            0.0              0.0
# Sikkim                                12.7            0.0              0.0
# Tripura                               26.8            0.0              0.0
# Uttarakhand                            0.0            0.0              0.0
# Andaman & Nicobar                     10.5            0.0              0.0
# Chandigarh                             0.0           11.8              2.1
# Dadra & Nagar Haveli                   0.0            0.0              0.0
# Daman & Diu                            0.0            0.0              0.0
# Lakshadweep                            0.0            0.0              0.0
# Puducherry                             0.0            0.0              0.0
#
#                       Sikhs - Persons
# States
# Andhra Pradesh                    0.0
# Assam                             0.0
# Bihar                             0.0
# Chhattisgarh                      0.0
# Delhi                             0.0
# Goa                               0.0
# Gujarat                           0.0
# Haryana                          15.1
# Jharkhand                         0.0
# Karnataka                         0.0
# Kerala                            0.0
# Madhya Pradesh                    0.0
# Maharashtra                       0.0
# Orissa                            0.0
# Punjab                           18.7
# Raja st ha n                     30.3
# Tamil Nadu                        0.0
# Uttar Pradesh                    14.0
# West Bengal                       0.0
# Arunachal Pradesh                 0.0
# Himachal Pradesh                  0.0
# Jammu & Kashmir                   0.0
# Manipur                           0.0
# Meghalaya                         0.0
# Mizoram                           0.0
# Nagaland                          0.0
# Sikkim                            0.0
# Tripura                           0.0
# Uttarakhand                       0.0
# Andaman & Nicobar                 0.0
# Chandigarh                        7.6
# Dadra & Nagar Haveli              0.0
# Daman & Diu                       0.0
# Lakshadweep                       0.0
# Puducherry                        0.0

# %%
########### Dictionary for indian states ##################

text = '''Bihar, India	25.0961	85.3131
Arunachal Pradesh, India	28.2180	94.7278
Madhya Pradesh, India	23.473324	77.947998
Haryana, India	29.238478	76.431885
Chhattisgarh, India	21.295132	81.828232
Haryana, India	29.065773	76.040497
Maharashtra, India	19.601194	75.552979
Tripura, India	23.745127	91.746826
Andhra Pradesh, India	17.874857	78.100815
Karnataka, India	15.317277	75.713890
Kerala, India	10.850516	76.271080
Uttar Pradesh, India	28.207609	79.826660
Assam, India	26.244156	92.537842
Maharashtra, India	19.663280	75.300293
Tamil Nadu, India	11.127123	78.656891
Karnataka, India	15.317277	75.713890
West Bengal, India	22.978624	87.747803
Gujarat, India	22.309425	72.136230
Orissa, India	20.940920	84.803467
Raja st ha n, India	27.391277	73.432617
Himachal Pradesh, India	32.084206	77.571167'''

csv = text.split('\n')
dic = dict()
states = []
for x in csv:
    dic[x.split("\t")[0].split(",")[0] ] =str(x.split("\t")[1]) +","+ str( x.split("\t")[2])
    states.append(x.split("\t")[0].split(",")[0])

# %%
states
# Out:
# ['Bihar',
#  'Arunachal Pradesh',
#  'Madhya Pradesh',
#  'Haryana',
#  'Chhattisgarh',
#  'Haryana',
#  'Maharashtra',
#  'Tripura',
#  'Andhra Pradesh',
#  'Karnataka',
#  'Kerala',
#  'Uttar Pradesh',
#  'Assam',
#  'Maharashtra',
#  'Tamil Nadu',
#  'Karnataka',
#  'West Bengal',
#  'Gujarat',
#  'Orissa',
#  'Raja st ha n',
#  'Himachal Pradesh']

# %%
dic
# Out:
# {'Bihar': '25.0961,85.3131',
#  'Arunachal Pradesh': '28.2180,94.7278',
#  'Madhya Pradesh': '23.473324,77.947998',
#  'Haryana': '29.065773,76.040497',
#  'Chhattisgarh': '21.295132,81.828232',
#  'Maharashtra': '19.663280,75.300293',
#  'Tripura': '23.745127,91.746826',
#  'Andhra Pradesh': '17.874857,78.100815',
#  'Karnataka': '15.317277,75.713890',
#  'Kerala': '10.850516,76.271080',
#  'Uttar Pradesh': '28.207609,79.826660',
#  'Assam': '26.244156,92.537842',
#  'Tamil Nadu': '11.127123,78.656891',
#  'West Bengal': '22.978624,87.747803',
#  'Gujarat': '22.309425,72.136230',
#  'Orissa': '20.940920,84.803467',
#  'Raja st ha n': '27.391277,73.432617',
#  'Himachal Pradesh': '32.084206,77.571167'}

# %%
df_states.fillna(0, inplace=True)

# %%
for state in states:
    val = df_states.loc[state, "Hindus - Persons"]
    pop = "<b>No. of Children<br>Age 6 - 17<br>Outside of School  :" + str(val) + "</b>"
    folium.CircleMarker(radius = int(val)+5,
              location = [float(dic[state].split(',')[0]), float(dic[state].split(',')[1])],
              popup=pop,
              tooltip="<b>"+state+"</b>",
              color='#3186cc',
              fill=True,
              fill_color='#3186cc').add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
